# %% [markdown]
# <a href="https://colab.research.google.com/github/alemjarebica-cloud/ML-flyrank-AlemJ/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/alemjarebica-cloud/ML-flyrank-AlemJ/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I am choosing lane 1: Ranking Signal Analysis. I am interested in understanding which content and search signals are associated with visibility and engagement outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Lane: Ranking Signal Analysis")
print(f"Working with {df.shape[0]} rows, {df.shape[1]} columns")
print(f"Key signals available: ctr, avg_position, engagement_rate, word_count, trend_direction")
# Out:
# Lane: Ranking Signal Analysis
# Working with 30000 rows, 44 columns
# Key signals available: ctr, avg_position, engagement_rate, word_count, trend_direction

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# For decision, which pages to prioritize for content refresh or update. For who acts on it, The content or SEO team. They decide where to spend limited time and budget on updating existing content. For costs, false positive and false negative.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(f"Share of pages trending down: {(df['trend_direction']=='down').mean():.1%}")
# Out:
# Share of pages trending down: 54.2%

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# Quick look at the data (starter dataset, 30,000 rows, 44 columns):
#
# - trend_direction breakdown: down 16,262 · stable 5,962 · up 4,388 ·
#   new 2,236 · flat 1,152. Over half the pages (54%) are trending down,
#   a large enough share to make prioritization genuinely useful.
#
# - Mean CTR by trend_direction: declining pages average 0.324% CTR,
#   noticeably lower than stable (0.517%) or up-trending pages (0.566%).
#   This suggests CTR is one signal worth investigating further.
#
# - Mean avg_position (excluding no-data rows) by trend_direction:
#   declining pages average position 15.94, while up-trending pages
#   average a worse position (22.51), a reminder that these are
#   observed associations, not a clean story, and worth digging into
#   rather than assuming.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print(f"Dataset: {df.shape[0]} rows, {df.shape[1]} columns")

print(f"\nTrend direction breakdown:\n{df['trend_direction'].value_counts()}")

ctr_by_trend = df.groupby("trend_direction")["ctr"].mean()
print(f"\nMean CTR by trend_direction:\n{ctr_by_trend.round(3)}")

valid_pos = df[df["avg_position"] > 0]
pos_by_trend = valid_pos.groupby("trend_direction")["avg_position"].mean()
print(f"\nMean avg_position by trend_direction (excluding no-data rows):\n{pos_by_trend.round(2)}")
# Out:
# Dataset: 30000 rows, 44 columns
#
# Trend direction breakdown:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Mean CTR by trend_direction:
# trend_direction
# down      0.324
# flat      1.377
# new       1.297
# stable    0.517
# up        0.566
# Name: ctr, dtype: float64
#
# Mean avg_position by trend_direction (excluding no-data rows):
# trend_direction
# down      15.94
# flat      11.53
# new       20.48
# stable    16.33
# up        22.51
# Name: avg_position, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What this work can say: observed associations between content/search
# signals (CTR, position, word count, etc.) and trend direction,
# directional patterns (e.g. "declining pages tend to have lower CTR"),
# decision-support recommendations (e.g. "prioritize pages with X
# combination of signals for review").
#
# What this work will never say: that any signal causally causes a
# page to decline, that we have reverse-engineered or "predicted"
# Google's ranking algorithm, that a correlation proves a mechanism.
# We watched the data, we did not run an experiment, so causal claims
# are out of scope.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Confirm why trend_direction/trend_pct can't be used as features:
# they are literally the source of the label we'd be trying to predict.
print(df[["trend_pct", "trend_direction"]].head(10))
# Out:
#    trend_pct trend_direction
# 0      -41.4            down
# 1      -57.7            down
# 2      -60.9            down
# 3      -13.8          stable
# 4      -34.7            down
# 5      -38.9            down
# 6      -92.3            down
# 7        0.6          stable
# 8      -58.8            down
# 9      -29.2            down

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
